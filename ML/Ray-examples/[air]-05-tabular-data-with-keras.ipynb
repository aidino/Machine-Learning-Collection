# %% [markdown]
# # Tabular data training and serving with Keras and Ray AIR
#
# Source: https://docs.ray.io/en/latest/ray-air/examples/tfx_tabular_train_to_serve.html

# %% [markdown]
# ## Setup Ray

# %%
from pprint import pprint
import ray

if ray.is_initialized():
    ray.shutdown()

ray.init()
# Out:
# 2023-09-06 09:23:24,126	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.9.18', ray_version='2.6.3', ray_commit='8a434b4ee7cd48e60fa1531315d39901fac5d79e', protocol_version=None)

# %%
pprint(ray.cluster_resources())
# Out:
# {'CPU': 20.0,
#  'GPU': 1.0,
#  'accelerator_type:G': 1.0,
#  'memory': 7054123008.0,
#  'node:192.168.33.188': 1.0,
#  'node:__internal_head__': 1.0,
#  'object_store_memory': 3527061504.0}

# %% [markdown]
# ## Getting the data

# %%
import pandas as pd 

INPUT = "input"
LABEL = "is_big_tip"

import pandas as pd

INPUT = "input"
LABEL = "is_big_tip"

def get_data() -> pd.DataFrame:
    """Fetch the taxi fare data to work on."""
    _data = pd.read_csv(
        "https://raw.githubusercontent.com/tensorflow/tfx/master/"
        "tfx/examples/chicago_taxi_pipeline/data/simple/data.csv"
    )
    _data[LABEL] = _data["tips"] / _data["fare"] > 0.2
    # We drop some columns here for the sake of simplicity.
    return _data.drop(
        [
            "tips",
            "fare",
            "dropoff_latitude",
            "dropoff_longitude",
            "pickup_latitude",
            "pickup_longitude",
            "pickup_census_tract",
        ],
        axis=1,
    )

# %%
data = get_data()
data.head()
# Out:
#    pickup_community_area  trip_start_month  trip_start_hour  trip_start_day  \
# 0                    NaN                 5               19               6
# 1                    NaN                 3               19               5
# 2                   60.0                10                2               3
# 3                   10.0                10                1               2
# 4                   14.0                 5                7               5
#
#    trip_start_timestamp  trip_miles  dropoff_census_tract payment_type  \
# 0            1400269500         0.0                   NaN  Credit Card
# 1            1362683700         0.0                   NaN      Unknown
# 2            1380593700        12.6                   NaN         Cash
# 3            1382319000         0.0                   NaN         Cash
# 4            1369897200         0.0                   NaN         Cash
#
#                                     company  trip_seconds  \
# 0  Chicago Elite Cab Corp. (Chicago Carriag           0.0
# 1                   Chicago Elite Cab Corp.         300.0
# 2                 Taxi Affiliation Services        1380.0
# 3                 Taxi Affiliation Services         180.0
# 4                 Dispatch Taxi Affiliation        1080.0
#
#    dropoff_community_area  is_big_tip
# 0                     NaN       False
# 1                     NaN       False
# 2                     NaN       False
# 3                     NaN       False
# 4                     NaN       False

# %% [markdown]
# ### Spliting the data to training set and test set

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from typing import Tuple

def split_data(data: pd.DataFrame) -> Tuple[ray.data.Dataset, pd.DataFrame, np.array]:
    """Split the data in a stratified way.

    Returns:
        A tuple containing train dataset, test data and test label.
    """
    
    train_data, test_data = train_test_split(data, test_size=0.2, stratify=data[LABEL], random_state=1113)
    
    _train_ds = ray.data.from_pandas(train_data)
    _test_label = test_data[LABEL].values
    _test_df = test_data.drop(LABEL, axis=1)
    return _train_ds, _test_df, _test_label

train_ds, test_df, test_label = split_data(data)

# %%
train_ds.count(), test_df.shape, test_label.shape
# Out:
# (12001, (3001, 11), (3001,))

# %% [markdown]
# ## Preprocessing

# %%
from ray.data.preprocessors import (
    BatchMapper,
    Concatenator,
    Chain,
    OneHotEncoder,
    SimpleImputer,
)

def get_preprocessor():
    """Construct a chain of preprocessors."""
    imputer1 = SimpleImputer(
        ["dropoff_census_tract"], strategy="most_frequent"
    )
    imputer2 = SimpleImputer(
        ["pickup_community_area", "dropoff_community_area"],
        strategy="most_frequent",
    )
    imputer3 = SimpleImputer(["payment_type"], strategy="most_frequent")
    imputer4 = SimpleImputer(
        ["company"], strategy="most_frequent")
    imputer5 = SimpleImputer(
        ["trip_start_timestamp", "trip_miles", "trip_seconds"], strategy="mean"
    )

    ohe = OneHotEncoder(
        columns=[
            "trip_start_hour",
            "trip_start_day",
            "trip_start_month",
            "dropoff_census_tract",
            "pickup_community_area",
            "dropoff_community_area",
            "payment_type",
            "company",
        ],
        max_categories={
            "dropoff_census_tract": 25,
            "pickup_community_area": 20,
            "dropoff_community_area": 20,
            "payment_type": 2,
            "company": 7,
        },
    )

    def batch_mapper_fn(df):
        df["trip_start_year"] = pd.to_datetime(df["trip_start_timestamp"], unit="s").dt.year
        df = df.drop(["trip_start_timestamp"], axis=1)
        return df

    chained_pp = Chain(
        imputer1,
        imputer2,
        imputer3,
        imputer4,
        imputer5,
        ohe,
        BatchMapper(batch_mapper_fn, batch_format="pandas"),
        # Concatenate all columns, except LABEL into a single tensor column with name INPUT.
        Concatenator(output_column_name=INPUT, exclude=[LABEL])
    )
    return chained_pp

# %%
# Note that `INPUT_SIZE` here is corresponding to the dimension
# of the previously created tensor column during preprocessing.
# This is used to specify the input shape of Keras model.
INPUT_SIZE = 120
# The global training batch size. Based on `NUM_WORKERS`, each worker
# will get its own share of this batch size. For example, if
# `NUM_WORKERS = 2`, each worker will work on 4 samples per batch.
BATCH_SIZE = 32
# Number of epoch. Adjust it based on how quickly you want the run to be.
EPOCH = 1
# Number of training workers.
# Adjust this accordingly based on the resources you have!
NUM_WORKERS = 10

# %% [markdown]
# ## Training

# %%
import tensorflow as tf

def build_model():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.Input(shape=(INPUT_SIZE,)))
    model.add(tf.keras.layers.Dense(50, activation="relu"))
    model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
    return model

# %%
from ray.air import session, Checkpoint
from ray.train.tensorflow import TensorflowCheckpoint

def train_loop_per_worker():
    dataset_shard = session.get_dataset_shard("train")

    strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy()
    with strategy.scope():
        model = build_model()
        model.compile(
            loss="binary_crossentropy",
            optimizer="adam",
            metrics=["accuracy"],
        )

    for epoch in range(EPOCH):            
        tf_dataset = dataset_shard.to_tf(feature_columns=INPUT, label_columns=LABEL, batch_size=BATCH_SIZE, drop_last=True)

        model.fit(tf_dataset, verbose=0)
        # This saves checkpoint in a way that can be used by Ray Serve coherently.
        session.report(
            {},
            checkpoint=TensorflowCheckpoint.from_model(model),
        )

# %%
from ray.train.tensorflow import TensorflowTrainer
from ray.air.config import ScalingConfig

trainer = TensorflowTrainer(
    train_loop_per_worker=train_loop_per_worker,
    scaling_config=ScalingConfig(num_workers=NUM_WORKERS),
    datasets={"train": train_ds},
    preprocessor=get_preprocessor(),
)
result = trainer.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-09-06 09:49:51</td></tr>
# <tr><td>Running for: </td><td>00:00:14.74        </td></tr>
# <tr><td>Memory:      </td><td>26.1/30.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 11.0/20 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc                 </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_044cb_00000</td><td>TERMINATED</td><td>192.168.33.188:29228</td><td style="text-align: right;">     1</td><td style="text-align: right;">          10.966</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2023-09-06 09:49:36,785	INFO data_parallel_trainer.py:404 -- GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (pid=29228) 2023-09-06 09:49:37.753894: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# (pid=29228) 2023-09-06 09:49:37.779600: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (pid=29228) To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=29228) 2023-09-06 09:49:38.165139: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (TrainTrainable pid=29228) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (TensorflowTrainer pid=29228) The `preprocessor` arg to Trainer is deprecated. Apply preprocessor transformations ahead of time by calling `preprocessor.transform(ds)`. Support for the preprocessor arg will be dropped in a future release.
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(get_pd_value_counts)] -> AllToAllOperator[RandomizeBlockOrder]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (pid=29228) - RandomizeBlockOrder 1:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(SimpleImputer._transform_pandas)->MapBatches(get_pd_value_counts)] -> AllToAllOperator[RandomizeBlockOrder]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (pid=29228) - RandomizeBlockOrder 1:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(get_pd_value_counts)]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(get_pd_value_counts)]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (TensorflowTrainer pid=29228) Tip: Use `take_batch()` instead of `take() / show()` to return records in pandas or numpy batch format.
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)] -> AllToAllOperator[Aggregate]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) - Aggregate 1:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) Shuffle Map 2:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) Shuffle Reduce 3:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(get_pd_value_counts)]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (TensorflowTrainer pid=29228) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (TensorflowTrainer pid=29228) Starting distributed worker processes: ['29334 (192.168.33.188)', '29335 (192.168.33.188)', '29336 (192.168.33.188)', '29337 (192.168.33.188)', '29338 (192.168.33.188)', '29339 (192.168.33.188)', '29340 (192.168.33.188)', '29341 (192.168.33.188)', '29342 (192.168.33.188)', '29343 (192.168.33.188)']
# (TensorflowTrainer pid=29228) Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas)] -> AllToAllOperator[RandomizeBlockOrder]
# (TensorflowTrainer pid=29228) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (TensorflowTrainer pid=29228) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (RayTrainWorker pid=29340) 2023-09-06 09:49:41.615401: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`. [repeated 10x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (RayTrainWorker pid=29340) 2023-09-06 09:49:41.670411: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations. [repeated 10x across cluster]
# (RayTrainWorker pid=29340) To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags. [repeated 10x across cluster]
# (pid=29228) - RandomizeBlockOrder 1:   0%|          | 0/1 [00:00<?, ?it/s]
# (pid=29228) Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(SimpleImputer._transform_pandas)->MapBatches(OneHotEncoder._transform_pandas)->MapBatches(BatchMapper._transform_pandas)->MapBatches(Concatenator._transform_pandas) pid=29272)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (RayTrainWorker pid=29340) 2023-09-06 09:49:42.523868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT [repeated 10x across cluster]
# (RayTrainWorker pid=29334) WARNING:tensorflow:From /tmp/ipykernel_25888/1282750181.py:7: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# (RayTrainWorker pid=29334) Instructions for updating:
# (RayTrainWorker pid=29334) use distribute.MultiWorkerMirroredStrategy instead
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.578436: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.578451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: fedora
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.578454: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: fedora
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.578545: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 535.98.0
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.578555: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 535.98.0
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.578557: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 535.98.0
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.586398: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:449] Started server with target: grpc://192.168.33.188:44727
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.594133: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:2 has connected to coordination service. Incarnation: 12339083157456496037
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.596596: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:3 has connected to coordination service. Incarnation: 8101269254479521940
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.596631: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:1 has connected to coordination service. Incarnation: 13572588113030005524
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.601175: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:9 has connected to coordination service. Incarnation: 2150662014210589658
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.609997: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:5 has connected to coordination service. Incarnation: 4725806659859574805
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.615442: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:0 has connected to coordination service. Incarnation: 8212334933176123212
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.615587: I tensorflow/tsl/distributed_runtime/coordination/coordination_service_agent.cc:298] Coordination agent has successfully connected.
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.615611: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:8 has connected to coordination service. Incarnation: 12241112847111057299
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.618335: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:6 has connected to coordination service. Incarnation: 16213060334403731259
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.621761: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:4 has connected to coordination service. Incarnation: 13157756154963963425
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.621798: I tensorflow/tsl/distributed_runtime/coordination/coordination_service.cc:535] /job:worker/replica:0/task:7 has connected to coordination service. Incarnation: 10037964564674556331
# (RayTrainWorker pid=29334) 2023-09-06 09:49:43.892218: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2023-09-06 09:49:51,519	INFO tune.py:1148 -- Total run time: 14.75 seconds (14.73 seconds for the tuning loop).

# %% [markdown]
# ## Moving on to Serve

# %%
from ray import serve
from ray.air.checkpoint import Checkpoint
from ray.train.tensorflow import TensorflowPredictor
from ray.serve import PredictorDeployment
from ray.serve.http_adapters import pandas_read_json

def serve_model(checkpoint: Checkpoint, model_definition, name="Model") -> str:
    """Expose a serve endpoint.

    Returns:
        serve URL.
    """
    serve.run(
        PredictorDeployment.options(name=name).bind(
            TensorflowPredictor,
            checkpoint,
            model_definition=model_definition,
            http_adapter=pandas_read_json,
        )
    )
    return f"http://localhost:8000/"

# %%
import ray
# Generally speaking, training and serving are done in totally different ray clusters.
# To simulate that, let's shutdown the old ray cluster in preparation for serving.
ray.shutdown()

endpoint_uri = serve_model(result.checkpoint, build_model)
# Out:
# 2023-09-06 09:52:08,992	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (HTTPProxyActor pid=33765) INFO:     Started server process [33765]
# (ServeController pid=33742) INFO 2023-09-06 09:52:11,055 controller 33742 deployment_state.py:1308 - Deploying new version of deployment default_Model.
# (ServeController pid=33742) INFO 2023-09-06 09:52:11,158 controller 33742 deployment_state.py:1571 - Adding 1 replica to deployment default_Model.
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:11.933455: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:11.965000: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (ServeReplica:default_Model pid=33801) To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.345888: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.689368: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.689390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: fedora
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.689393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: fedora
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.689477: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 535.98.0
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.689487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 535.98.0
# (ServeReplica:default_Model pid=33801) 2023-09-06 09:52:12.689489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 535.98.0
# 2023-09-06 09:52:12,970	INFO router.py:853 -- Using PowerOfTwoChoicesReplicaScheduler.
# 2023-09-06 09:52:12,974	INFO router.py:329 -- Got updated replicas for deployment default_Model: {'default_Model#CjKzIu'}.

# %%
import json
import requests
import pandas as pd
import numpy as np

NUM_SERVE_REQUESTS = 10

def send_requests(df: pd.DataFrame, label: np.array):
    for i in range(NUM_SERVE_REQUESTS):
        one_row = df.iloc[[i]].to_dict()
        serve_result = requests.post(endpoint_uri, data=json.dumps(one_row), headers={"Content-Type": "application/json"}).json()
        print(
            f"request{i} prediction: {serve_result[0]['predictions']} "
            f"- label: {str(label[i])}"
        )

# %%
send_requests(test_df, test_label)
# Out:
# request0 prediction: [0.027962926775217056] - label: False
# request1 prediction: [0.06391758471727371] - label: False
# request2 prediction: [0.11197128146886826] - label: False
# request3 prediction: [0.24359434843063354] - label: False
# request4 prediction: [0.07752858847379684] - label: False
# request5 prediction: [0.001054437831044197] - label: False
# request6 prediction: [0.07377337664365768] - label: False
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/serve/http_adapters.py:106: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# (ServeReplica:default_Model pid=33801)   return pd.read_json(raw_json, **raw_request.query_params)
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /tmp/ipykernel_25888/2133510648.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801) Missing columns specified in 'exclude': {'is_big_tip'}
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
# (ServeReplica:default_Model pid=33801)   return bound(*args, **kwds)
# (ServeReplica:default_Model pid=33801) INFO 2023-09-06 09:52:40,704 default_Model default_Model#CjKzIu ZIBrcAZUaI / default replica.py:723 - __CALL__ OK 43.7ms
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/serve/http_adapters.py:106: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# (ServeReplica:default_Model pid=33801)   return pd.read_json(raw_json, **raw_request.query_params)
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /tmp/ipykernel_25888/2133510648.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801) Missing columns specified in 'exclude': {'is_big_tip'}
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
# (ServeReplica:default_Model pid=33801)   return bound(*args, **kwds)
# (ServeReplica:default_Model pid=33801) INFO 2023-09-06 09:52:40,740 default_Model default_Model#CjKzIu WXMlzmRcbE / default replica.py:723 - __CALL__ OK 31.5ms
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/serve/http_adapters.py:106: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# (ServeReplica:default_Model pid=33801)   return pd.read_json(raw_json, **raw_request.query_params)
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /tmp/ipykernel_25888/2133510648.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801) Missing columns specified in 'exclude': {'is_big_tip'}
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
# (ServeReplica:default_Model pid=33801)   return bound(*args, **kwds)
# (ServeReplica:default_Model pid=33801) INFO 2023-09-06 09:52:40,773 default_Model default_Model#CjKzIu JKnXfRYYak / default replica.py:723 - __CALL__ OK 26.9ms
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/serve/http_adapters.py:106: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# (ServeReplica:default_Model pid=33801)   return pd.read_json(raw_json, **raw_request.query_params)
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# ...
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /tmp/ipykernel_25888/2133510648.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801) Missing columns specified in 'exclude': {'is_big_tip'}
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
# (ServeReplica:default_Model pid=33801)   return bound(*args, **kwds)
# (ServeReplica:default_Model pid=33801) INFO 2023-09-06 09:52:40,967 default_Model default_Model#CjKzIu PODFoFjngE / default replica.py:723 - __CALL__ OK 27.2ms
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/serve/http_adapters.py:106: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# (ServeReplica:default_Model pid=33801)   return pd.read_json(raw_json, **raw_request.query_params)
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/ray/data/preprocessors/encoder.py:229: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801)   df[f"{column}_{column_value}"] = (df[column] == column_value).astype(
# (ServeReplica:default_Model pid=33801) /tmp/ipykernel_25888/2133510648.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# (ServeReplica:default_Model pid=33801) Missing columns specified in 'exclude': {'is_big_tip'}
# (ServeReplica:default_Model pid=33801) /home/mpp/.conda/envs/ray/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
# (ServeReplica:default_Model pid=33801)   return bound(*args, **kwds)
# (ServeReplica:default_Model pid=33801) INFO 2023-09-06 09:52:41,001 default_Model default_Model#CjKzIu EQySPcLeOe / default replica.py:723 - __CALL__ OK 26.5ms
