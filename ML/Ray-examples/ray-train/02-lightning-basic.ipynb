# %% [markdown]
# # Train a Pytorch Lightning Image Classifier
#
# This example introduces how to train a Pytorch Lightning Module using AIR LightningTrainer. We will demonstrate how to train a basic neural network on the MNIST dataset with distributed data parallelism.
#
# Source: https://docs.ray.io/en/latest/train/examples/lightning/lightning_mnist_example.html

# %%
# Requirements:
# ray, torchmetrics, pytorch_lightning

# %%
import os
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from filelock import FileLock # for handling concurrent writes
from torch.utils.data import DataLoader, random_split, Subset
from torchmetrics import Accuracy
from torchvision.datasets import MNIST
from torchvision import transforms

import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.loggers.csv_logs import CSVLogger

# %% [markdown]
# ## Prepare Dataset and Module

# %%
class MNISTDataModule(pl.LightningDataModule):
    def __init__(self, batch_size=100):
        super().__init__()
        self.data_dir = os.getcwd()
        self.batch_size = batch_size
        self.transform = transforms.Compose(
            [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
        )

    def setup(self, stage=None):
        with FileLock(f"{self.data_dir}.lock"):
            mnist = MNIST(
                self.data_dir, train=True, download=True, transform=self.transform
            )

            # split data into train and val sets
            self.mnist_train, self.mnist_val = random_split(mnist, [55000, 5000])

    def train_dataloader(self):
        return DataLoader(self.mnist_train, batch_size=self.batch_size, num_workers=4)

    def val_dataloader(self):
        return DataLoader(self.mnist_val, batch_size=self.batch_size, num_workers=4)

    def test_dataloader(self):
        with FileLock(f"{self.data_dir}.lock"):
            self.mnist_test = MNIST(
                self.data_dir, train=False, download=True, transform=self.transform
            )
        return DataLoader(self.mnist_test, batch_size=self.batch_size, num_workers=4)


datamodule = MNISTDataModule(batch_size=128)

# %% [markdown]
# Next, define a simple multi-layer perception as the subclass of `pl.LightningModule`.

# %%
class MNISTClassifier(pl.LightningModule):
    def __init__(self, lr=1e-3, feature_dim=128):
        torch.manual_seed(421)
        super(MNISTClassifier, self).__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28 * 28, feature_dim),
            nn.ReLU(),
            nn.Linear(feature_dim, 10),
            nn.ReLU(),
        )
        self.lr = lr
        self.accuracy = Accuracy(task="multiclass", num_classes=10)
        self.eval_loss = []
        self.eval_accuracy = []
        self.test_accuracy = []
        pl.seed_everything(888)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.linear_relu_stack(x)
        return x

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = torch.nn.functional.cross_entropy(y_hat, y)
        self.log("train_loss", loss)
        return loss

    def validation_step(self, val_batch, batch_idx):
        loss, acc = self._shared_eval(val_batch)
        self.log("val_accuracy", acc)
        self.eval_loss.append(loss)
        self.eval_accuracy.append(acc)
        return {"val_loss": loss, "val_accuracy": acc}

    def test_step(self, test_batch, batch_idx):
        loss, acc = self._shared_eval(test_batch)
        self.test_accuracy.append(acc)
        self.log("test_accuracy", acc, sync_dist=True, on_epoch=True)
        return {"test_loss": loss, "test_accuracy": acc}

    def _shared_eval(self, batch):
        x, y = batch
        logits = self.forward(x)
        loss = F.nll_loss(logits, y)
        acc = self.accuracy(logits, y)
        return loss, acc

    def on_validation_epoch_end(self):
        avg_loss = torch.stack(self.eval_loss).mean()
        avg_acc = torch.stack(self.eval_accuracy).mean()
        self.log("val_loss", avg_loss, sync_dist=True)
        self.log("val_accuracy", avg_acc, sync_dist=True)
        self.eval_loss.clear()
        self.eval_accuracy.clear()
    
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.lr)
        return optimizer

# %% [markdown]
# ## Define the Cofigurations for AIR LightningTrainer
#
# The `LightningConfigBuilder` class stores all the parameters involved in training a PyTorch Lightning module. It takes the same parameter lists as those in PyTorch Lightning.
#
# - The `.module()` method takes a subclass of pl.LightningModule and its initialization parameters. `LightningTrainer` will instantiate a model instance internally in the workers’ training loop.
#
# - The `.trainer()` method takes the initialization parameters of `pl.Trainer`. You can specify training configurations, loggers, and callbacks here.
#
# - The `.fit_params()` method stores all the parameters that will be passed into `pl.Trainer.fit()`, including train/val dataloaders, datamodules, and checkpoint paths.
#
# - The `.checkpointing()` method saves the configurations for a `RayModelCheckpoint` callback. This callback reports the latest metrics to the AIR session along with a newly saved checkpoint.
#
# - The `.build()` method generates a dictionary that contains all the configurations in the builder. This dictionary will be passed to `LightningTrainer` later.

# %%
from pytorch_lightning.callbacks import ModelCheckpoint
from ray.air.config import RunConfig, ScalingConfig, CheckpointConfig
from ray.train.lightning import (
    LightningTrainer,
    LightningConfigBuilder,
    LightningCheckpoint,
)


def build_lightning_config_from_existing_code(use_gpu):
    # Create a config builder to encapsulate all required parameters.
    # Note that model instantiation and fitting will occur later in the LightingTrainer,
    # rather than in the config builder.
    config_builder = LightningConfigBuilder()

    # 1. define your model
    # model = MNISTClassifier(lr=1e-3, feature_dim=128)
    config_builder.module(cls=MNISTClassifier, lr=1e-3, feature_dim=128)

    # 2. define a ModelCheckpoint callback
    # checkpoint_callback = ModelCheckpoint(
    #     monitor="val_accuracy", mode="max", save_top_k=3
    # )
    config_builder.checkpointing(monitor="val_accuracy", mode="max", save_top_k=3)

    # 3. Define a Lightning trainer
    # trainer = pl.Trainer(
    #     max_epochs=10,
    #     accelerator="cpu",
    #     strategy="ddp",
    #     log_every_n_steps=100,
    #     logger=CSVLogger("logs"),
    #     callbacks=[checkpoint_callback],
    # )
    config_builder.trainer(
        max_epochs=10,
        accelerator="gpu" if use_gpu else "cpu",
        log_every_n_steps=100,
        logger=CSVLogger("logs"),
    )
    # You do not need to provide the checkpoint callback and strategy here,
    # since LightningTrainer configures them automatically.
    # You can also add any other callbacks into LightningConfigBuilder.trainer().

    # 4. Parameters for model fitting
    # trainer.fit(model, datamodule=datamodule)
    config_builder.fit_params(datamodule=datamodule)

    # Finally, compile all the configs into a dictionary for LightningTrainer
    lightning_config = config_builder.build()
    return lightning_config

# %%
use_gpu = True # Set it to False if you want to run without GPUs
num_workers = 1

# %%
lightning_config = build_lightning_config_from_existing_code(use_gpu=use_gpu)

scaling_config = ScalingConfig(num_workers=num_workers, use_gpu=use_gpu)

run_config = RunConfig(
    name="ptl-mnist-example",
    storage_path="/tmp/ray_results",
    checkpoint_config=CheckpointConfig(
        num_to_keep=3,
        checkpoint_score_attribute="val_accuracy",
        checkpoint_score_order="max",
    ),
)

trainer = LightningTrainer(
    lightning_config=lightning_config,
    scaling_config=scaling_config,
    run_config=run_config,
)

# %%
result = trainer.fit()
print("Validation Accuracy: ", result.metrics["val_accuracy"])
result
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-09-06 23:32:04</td></tr>
# <tr><td>Running for: </td><td>00:00:37.63        </td></tr>
# <tr><td>Memory:      </td><td>12.2/31.2 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/16 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                  </th><th>status    </th><th>loc                 </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  val_accuracy</th><th style="text-align: right;">  val_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>LightningTrainer_d3314_00000</td><td>TERMINATED</td><td>192.168.1.147:700772</td><td style="text-align: right;">    10</td><td style="text-align: right;">         31.5043</td><td style="text-align: right;">   0.0504907</td><td style="text-align: right;">      0.970508</td><td style="text-align: right;">  -15.8305</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (LightningTrainer pid=700772) Starting distributed worker processes: ['700925 (192.168.1.147)']
# (RayTrainWorker pid=700925) Setting up process group for: env:// [rank=0, world_size=1]
# (RayTrainWorker pid=700925) [rank: 0] Global seed set to 888
# (RayTrainWorker pid=700925) GPU available: True (cuda), used: True
# (RayTrainWorker pid=700925) TPU available: False, using: 0 TPU cores
# (RayTrainWorker pid=700925) IPU available: False, using: 0 IPUs
# (RayTrainWorker pid=700925) HPU available: False, using: 0 HPUs
# (RayTrainWorker pid=700925) [rank: 0] Global seed set to 888
# (RayTrainWorker pid=700925) You are using a CUDA device ('NVIDIA GeForce RTX 3070') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Sanity Checking: 0it [00:00, ?it/s])
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# (RayTrainWorker pid=700925) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (RayTrainWorker pid=700925)
# (RayTrainWorker pid=700925)   | Name              | Type               | Params
# (RayTrainWorker pid=700925) ---------------------------------------------------------
# (RayTrainWorker pid=700925) 0 | linear_relu_stack | Sequential         | 101 K
# (RayTrainWorker pid=700925) 1 | accuracy          | MulticlassAccuracy | 0
# (RayTrainWorker pid=700925) ---------------------------------------------------------
# (RayTrainWorker pid=700925) 101 K     Trainable params
# (RayTrainWorker pid=700925) 0         Non-trainable params
# (RayTrainWorker pid=700925) 101 K     Total params
# (RayTrainWorker pid=700925) 0.407     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/430 [00:00<?, ?it/s]
# (RayTrainWorker pid=700925) /home/dino/anaconda3/envs/ray/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('val_accuracy', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# (RayTrainWorker pid=700925)   warning_cache.warn(
# Epoch 0:   2%|▏         | 8/430 [00:00<00:10, 38.79it/s, v_num=0]
# Epoch 0:   7%|▋         | 31/430 [00:00<00:04, 96.46it/s, v_num=0]
# Epoch 0:  12%|█▏        | 53/430 [00:00<00:03, 124.82it/s, v_num=0]
# Epoch 0:  12%|█▏        | 53/430 [00:00<00:03, 124.77it/s, v_num=0]
# Epoch 0:  18%|█▊        | 76/430 [00:00<00:02, 146.56it/s, v_num=0]
# Epoch 0:  18%|█▊        | 77/430 [00:00<00:02, 145.61it/s, v_num=0]
# Epoch 0:  23%|██▎       | 100/430 [00:00<00:02, 159.32it/s, v_num=0]
# Epoch 0:  28%|██▊       | 121/430 [00:00<00:01, 165.23it/s, v_num=0]
# Epoch 0:  28%|██▊       | 122/430 [00:00<00:01, 165.79it/s, v_num=0]
# Epoch 0:  33%|███▎      | 141/430 [00:00<00:01, 168.28it/s, v_num=0]
# Epoch 0:  38%|███▊      | 165/430 [00:00<00:01, 175.45it/s, v_num=0]
# Epoch 0:  44%|████▎     | 188/430 [00:01<00:01, 180.86it/s, v_num=0]
# Epoch 0:  44%|████▍     | 189/430 [00:01<00:01, 181.27it/s, v_num=0]
# Epoch 0:  50%|████▉     | 213/430 [00:01<00:01, 186.76it/s, v_num=0]
# Epoch 0:  50%|████▉     | 214/430 [00:01<00:01, 186.76it/s, v_num=0]
# Epoch 0:  55%|█████▌    | 237/430 [00:01<00:01, 190.37it/s, v_num=0]
# Epoch 0:  55%|█████▌    | 238/430 [00:01<00:01, 190.55it/s, v_num=0]
# Epoch 0:  60%|██████    | 260/430 [00:01<00:00, 193.63it/s, v_num=0]
# Epoch 0:  61%|██████    | 261/430 [00:01<00:00, 192.86it/s, v_num=0]
# Epoch 0:  66%|██████▌   | 284/430 [00:01<00:00, 195.82it/s, v_num=0]
# Epoch 0:  71%|███████   | 304/430 [00:01<00:00, 197.03it/s, v_num=0]
# Epoch 0:  74%|███████▍  | 319/430 [00:01<00:00, 192.29it/s, v_num=0]
# Epoch 0:  74%|███████▍  | 320/430 [00:01<00:00, 192.54it/s, v_num=0]
# Epoch 0:  78%|███████▊  | 337/430 [00:01<00:00, 192.26it/s, v_num=0]
# Epoch 0:  79%|███████▊  | 338/430 [00:01<00:00, 191.59it/s, v_num=0]
# Epoch 0:  83%|████████▎ | 358/430 [00:01<00:00, 192.12it/s, v_num=0]
# Epoch 0:  88%|████████▊ | 377/430 [00:01<00:00, 191.66it/s, v_num=0]
# Epoch 0:  93%|█████████▎| 399/430 [00:02<00:00, 192.73it/s, v_num=0]
# Epoch 0:  98%|█████████▊| 420/430 [00:02<00:00, 193.57it/s, v_num=0]
# Epoch 0: 100%|██████████| 430/430 [00:02<00:00, 194.21it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 337.90it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 251.34it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 291.70it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 319.46it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 271.00it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 224.68it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 247.51it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 268.68it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 255.43it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 224.74it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 238.87it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 252.25it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 246.42it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 224.92it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 235.10it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 244.97it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 243.22it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 225.21it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 233.10it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 241.04it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 240.55it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 225.43it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 232.05it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 238.57it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 236.51it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 225.31it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 230.83it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 236.21it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 237.23it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 224.37it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 228.28it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 232.60it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 235.83it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 224.24it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 228.23it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 232.46it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 235.06it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 225.88it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 229.78it/s]
# Epoch 0: 100%|██████████| 430/430 [00:02<00:00, 171.84it/s, v_num=0]it/s]
# Epoch 0: 100%|██████████| 430/430 [00:02<00:00, 171.80it/s, v_num=0]
# Epoch 1:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 1:   3%|▎         | 12/430 [00:00<00:06, 66.73it/s, v_num=0]
# Epoch 1:   7%|▋         | 32/430 [00:00<00:03, 112.32it/s, v_num=0]
# Epoch 1:  11%|█         | 48/430 [00:00<00:02, 129.56it/s, v_num=0]
# Epoch 1:  15%|█▌        | 65/430 [00:00<00:02, 133.76it/s, v_num=0]
# Epoch 1:  20%|██        | 88/430 [00:00<00:02, 150.62it/s, v_num=0]
# Epoch 1:  21%|██        | 89/430 [00:00<00:02, 150.32it/s, v_num=0]
# Epoch 1:  26%|██▌       | 112/430 [00:00<00:01, 162.01it/s, v_num=0]
# Epoch 1:  31%|███▏      | 135/430 [00:00<00:01, 170.32it/s, v_num=0]
# Epoch 1:  37%|███▋      | 158/430 [00:00<00:01, 176.07it/s, v_num=0]
# Epoch 1:  37%|███▋      | 158/430 [00:00<00:01, 176.04it/s, v_num=0]
# Epoch 1:  42%|████▏     | 180/430 [00:00<00:01, 180.26it/s, v_num=0]
# Epoch 1:  42%|████▏     | 181/430 [00:01<00:01, 180.83it/s, v_num=0]
# Epoch 1:  47%|████▋     | 203/430 [00:01<00:01, 185.24it/s, v_num=0]
# Epoch 1:  47%|████▋     | 204/430 [00:01<00:01, 184.74it/s, v_num=0]
# Epoch 1:  52%|█████▏    | 225/430 [00:01<00:01, 186.75it/s, v_num=0]
# Epoch 1:  58%|█████▊    | 248/430 [00:01<00:00, 189.73it/s, v_num=0]
# Epoch 1:  58%|█████▊    | 249/430 [00:01<00:00, 190.13it/s, v_num=0]
# Epoch 1:  63%|██████▎   | 270/430 [00:01<00:00, 192.19it/s, v_num=0]
# Epoch 1:  67%|██████▋   | 290/430 [00:01<00:00, 191.87it/s, v_num=0]
# Epoch 1:  72%|███████▏  | 310/430 [00:01<00:00, 192.78it/s, v_num=0]
# Epoch 1:  78%|███████▊  | 334/430 [00:01<00:00, 195.18it/s, v_num=0]
# Epoch 1:  78%|███████▊  | 335/430 [00:01<00:00, 194.87it/s, v_num=0]
# Epoch 1:  81%|████████  | 348/430 [00:01<00:00, 191.25it/s, v_num=0]
# Epoch 1:  81%|████████  | 349/430 [00:01<00:00, 191.51it/s, v_num=0]
# Epoch 1:  85%|████████▌ | 366/430 [00:01<00:00, 190.65it/s, v_num=0]
# Epoch 1:  91%|█████████ | 391/430 [00:02<00:00, 192.91it/s, v_num=0]
# Epoch 1:  97%|█████████▋| 415/430 [00:02<00:00, 195.03it/s, v_num=0]
# Epoch 1:  97%|█████████▋| 416/430 [00:02<00:00, 195.28it/s, v_num=0]
# Epoch 1: 100%|██████████| 430/430 [00:02<00:00, 196.05it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 381.23it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 309.74it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 363.55it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 212.07it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 241.09it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 259.18it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 279.95it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 222.57it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 238.74it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 244.48it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 257.23it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 209.65it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 220.08it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 227.36it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 237.32it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 194.66it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 202.71it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 210.72it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 218.45it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 185.60it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 191.69it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 197.91it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 204.12it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 180.17it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 184.93it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 188.84it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 192.65it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 184.85it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 188.65it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 192.89it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 197.17it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 190.09it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 194.06it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 197.86it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 201.89it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 194.15it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 197.95it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 201.78it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 205.54it/s]
# Epoch 1: 100%|██████████| 430/430 [00:02<00:00, 171.81it/s, v_num=0]it/s]
# Epoch 1: 100%|██████████| 430/430 [00:02<00:00, 171.77it/s, v_num=0]
# Epoch 2:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 2:   1%|          | 5/430 [00:00<00:12, 33.94it/s, v_num=0]
# Epoch 2:   7%|▋         | 28/430 [00:00<00:03, 112.37it/s, v_num=0]
# Epoch 2:  12%|█▏        | 51/430 [00:00<00:02, 145.73it/s, v_num=0]
# Epoch 2:  12%|█▏        | 52/430 [00:00<00:02, 147.44it/s, v_num=0]
# Epoch 2:  16%|█▋        | 70/430 [00:00<00:02, 154.38it/s, v_num=0]
# Epoch 2:  17%|█▋        | 71/430 [00:00<00:02, 155.47it/s, v_num=0]
# Epoch 2:  20%|██        | 86/430 [00:00<00:02, 154.56it/s, v_num=0]
# Epoch 2:  24%|██▍       | 105/430 [00:00<00:02, 158.97it/s, v_num=0]
# Epoch 2:  29%|██▉       | 124/430 [00:00<00:01, 162.73it/s, v_num=0]
# Epoch 2:  34%|███▍      | 147/430 [00:00<00:01, 170.99it/s, v_num=0]
# Epoch 2:  34%|███▍      | 148/430 [00:00<00:01, 170.95it/s, v_num=0]
# Epoch 2:  40%|███▉      | 171/430 [00:00<00:01, 178.02it/s, v_num=0]
# Epoch 2:  40%|████      | 172/430 [00:00<00:01, 177.71it/s, v_num=0]
# Epoch 2:  46%|████▌     | 196/430 [00:01<00:01, 183.46it/s, v_num=0]
# Epoch 2:  46%|████▌     | 197/430 [00:01<00:01, 184.00it/s, v_num=0]
# Epoch 2:  46%|████▌     | 198/430 [00:01<00:01, 184.53it/s, v_num=0]
# Epoch 2:  46%|████▌     | 198/430 [00:01<00:01, 184.51it/s, v_num=0]
# Epoch 2:  51%|█████▏    | 221/430 [00:01<00:01, 188.07it/s, v_num=0]
# Epoch 2:  56%|█████▋    | 242/430 [00:01<00:00, 189.44it/s, v_num=0]
# Epoch 2:  61%|██████    | 262/430 [00:01<00:00, 190.82it/s, v_num=0]
# Epoch 2:  66%|██████▌   | 282/430 [00:01<00:00, 191.31it/s, v_num=0]
# Epoch 2:  71%|███████   | 306/430 [00:01<00:00, 193.92it/s, v_num=0]
# Epoch 2:  77%|███████▋  | 330/430 [00:01<00:00, 195.97it/s, v_num=0]
# Epoch 2:  82%|████████▏ | 353/430 [00:01<00:00, 197.40it/s, v_num=0]
# Epoch 2:  87%|████████▋ | 374/430 [00:01<00:00, 199.57it/s, v_num=0]
# Epoch 2:  91%|█████████▏| 393/430 [00:01<00:00, 197.34it/s, v_num=0]
# Epoch 2:  96%|█████████▌| 413/430 [00:02<00:00, 198.43it/s, v_num=0]
# Epoch 2: 100%|██████████| 430/430 [00:02<00:00, 197.84it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 447.34it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 496.04it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 535.24it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 476.50it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 470.74it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 493.68it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 485.73it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 482.50it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 354.82it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 342.71it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 356.29it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 368.71it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 303.98it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 298.85it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 308.71it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 319.04it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 284.98it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 246.07it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 250.17it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 252.90it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 235.74it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 219.89it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 225.63it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 231.22it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 225.08it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 208.83it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 212.27it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 215.66it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 214.84it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 204.18it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 207.59it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 211.06it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 211.03it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 201.10it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 204.11it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 207.15it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 210.27it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 200.93it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 204.53it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 208.11it/s]
# Epoch 2: 100%|██████████| 430/430 [00:02<00:00, 171.51it/s, v_num=0]
# Epoch 2: 100%|██████████| 430/430 [00:02<00:00, 171.46it/s, v_num=0]
# Epoch 3:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 3:   2%|▏         | 10/430 [00:00<00:08, 50.78it/s, v_num=0]
# Epoch 3:   6%|▌         | 25/430 [00:00<00:04, 85.06it/s, v_num=0]
# Epoch 3:   6%|▌         | 26/430 [00:00<00:04, 86.94it/s, v_num=0]
# Epoch 3:  10%|█         | 45/430 [00:00<00:03, 112.23it/s, v_num=0]
# Epoch 3:  14%|█▍        | 62/430 [00:00<00:02, 124.39it/s, v_num=0]
# Epoch 3:  18%|█▊        | 79/430 [00:00<00:02, 130.34it/s, v_num=0]
# Epoch 3:  22%|██▏       | 96/430 [00:00<00:02, 136.35it/s, v_num=0]
# Epoch 3:  27%|██▋       | 116/430 [00:00<00:02, 143.58it/s, v_num=0]
# Epoch 3:  27%|██▋       | 117/430 [00:00<00:02, 143.84it/s, v_num=0]
# Epoch 3:  30%|██▉       | 128/430 [00:00<00:02, 141.39it/s, v_num=0]
# Epoch 3:  34%|███▍      | 148/430 [00:01<00:01, 146.26it/s, v_num=0]
# Epoch 3:  39%|███▉      | 169/430 [00:01<00:01, 151.05it/s, v_num=0]
# Epoch 3:  44%|████▍     | 189/430 [00:01<00:01, 155.07it/s, v_num=0]
# Epoch 3:  49%|████▉     | 211/430 [00:01<00:01, 159.63it/s, v_num=0]
# Epoch 3:  49%|████▉     | 212/430 [00:01<00:01, 159.74it/s, v_num=0]
# Epoch 3:  49%|████▉     | 212/430 [00:01<00:01, 159.71it/s, v_num=0]
# Epoch 3:  55%|█████▍    | 235/430 [00:01<00:01, 164.64it/s, v_num=0]
# Epoch 3:  55%|█████▍    | 236/430 [00:01<00:01, 164.95it/s, v_num=0]
# Epoch 3:  59%|█████▉    | 253/430 [00:01<00:01, 165.64it/s, v_num=0]
# Epoch 3:  64%|██████▍   | 277/430 [00:01<00:00, 169.64it/s, v_num=0]
# Epoch 3:  70%|███████   | 301/430 [00:01<00:00, 173.23it/s, v_num=0]
# Epoch 3:  75%|███████▍  | 321/430 [00:01<00:00, 174.69it/s, v_num=0]
# Epoch 3:  80%|███████▉  | 342/430 [00:01<00:00, 176.33it/s, v_num=0]
# Epoch 3:  85%|████████▌ | 366/430 [00:02<00:00, 179.18it/s, v_num=0]
# Epoch 3:  89%|████████▉ | 383/430 [00:02<00:00, 178.58it/s, v_num=0]
# Epoch 3:  89%|████████▉ | 384/430 [00:02<00:00, 178.86it/s, v_num=0]
# Epoch 3:  94%|█████████▍| 406/430 [00:02<00:00, 181.06it/s, v_num=0]
# Epoch 3:  97%|█████████▋| 419/430 [00:02<00:00, 178.33it/s, v_num=0]
# Epoch 3: 100%|██████████| 430/430 [00:02<00:00, 179.75it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 460.41it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 404.82it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 394.30it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 400.54it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 403.66it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 407.50it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 411.90it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 416.51it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 419.31it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 384.01it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 388.20it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 332.85it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 337.84it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 321.97it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 320.23it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 295.55it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 296.46it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 280.74it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 285.91it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 283.27it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 284.93it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 256.24it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 260.56it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 262.27it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 263.95it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 241.95it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 245.86it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 249.93it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 253.85it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 233.29it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 236.85it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 240.43it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 243.99it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 227.27it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 230.29it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 233.62it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 236.92it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 225.49it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 229.39it/s]
# Epoch 3: 100%|██████████| 430/430 [00:02<00:00, 160.26it/s, v_num=0]it/s]
# Epoch 3: 100%|██████████| 430/430 [00:02<00:00, 160.23it/s, v_num=0]
# Epoch 4:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 4:   2%|▏         | 9/430 [00:00<00:08, 50.42it/s, v_num=0]
# Epoch 4:   7%|▋         | 29/430 [00:00<00:03, 103.46it/s, v_num=0]
# Epoch 4:  12%|█▏        | 51/430 [00:00<00:02, 134.86it/s, v_num=0]
# Epoch 4:  17%|█▋        | 72/430 [00:00<00:02, 148.38it/s, v_num=0]
# Epoch 4:  17%|█▋        | 72/430 [00:00<00:02, 148.33it/s, v_num=0]
# Epoch 4:  23%|██▎       | 98/430 [00:00<00:01, 166.82it/s, v_num=0]
# Epoch 4:  28%|██▊       | 121/430 [00:00<00:01, 175.52it/s, v_num=0]
# Epoch 4:  33%|███▎      | 144/430 [00:00<00:01, 182.19it/s, v_num=0]
# Epoch 4:  39%|███▉      | 167/430 [00:00<00:01, 187.88it/s, v_num=0]
# Epoch 4:  43%|████▎     | 185/430 [00:00<00:01, 188.21it/s, v_num=0]
# Epoch 4:  46%|████▋     | 199/430 [00:01<00:01, 181.31it/s, v_num=0]
# Epoch 4:  51%|█████     | 218/430 [00:01<00:01, 181.72it/s, v_num=0]
# Epoch 4:  56%|█████▌    | 241/430 [00:01<00:01, 185.54it/s, v_num=0]
# Epoch 4:  60%|██████    | 260/430 [00:01<00:00, 186.84it/s, v_num=0]
# Epoch 4:  66%|██████▌   | 282/430 [00:01<00:00, 187.65it/s, v_num=0]
# Epoch 4:  70%|███████   | 302/430 [00:01<00:00, 187.91it/s, v_num=0]
# Epoch 4:  75%|███████▍  | 321/430 [00:01<00:00, 188.08it/s, v_num=0]
# Epoch 4:  80%|███████▉  | 343/430 [00:01<00:00, 189.30it/s, v_num=0]
# Epoch 4:  85%|████████▌ | 367/430 [00:01<00:00, 191.90it/s, v_num=0]
# Epoch 4:  90%|█████████ | 387/430 [00:02<00:00, 192.08it/s, v_num=0]
# Epoch 4:  95%|█████████▍| 408/430 [00:02<00:00, 192.76it/s, v_num=0]
# Epoch 4:  95%|█████████▌| 409/430 [00:02<00:00, 192.93it/s, v_num=0]
# Epoch 4:  95%|█████████▌| 409/430 [00:02<00:00, 192.91it/s, v_num=0]
# Epoch 4: 100%|█████████▉| 429/430 [00:02<00:00, 193.11it/s, v_num=0]
# Epoch 4: 100%|██████████| 430/430 [00:02<00:00, 193.24it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 396.17it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 335.49it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 321.10it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 355.23it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 367.93it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 354.22it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 349.27it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 370.42it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 378.90it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 338.32it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 235.76it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 248.52it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 260.56it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 264.35it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 226.38it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 232.79it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 241.16it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 245.46it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 226.26it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 231.24it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 236.38it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 236.40it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 217.87it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 222.22it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 225.85it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 229.25it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 211.83it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 215.29it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 219.13it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 223.03it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 182.70it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 186.29it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 190.07it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 192.63it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 181.36it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 183.98it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 187.25it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 190.54it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 192.18it/s]
# Epoch 4: 100%|██████████| 430/430 [00:02<00:00, 167.74it/s, v_num=0]it/s]
# Epoch 4: 100%|██████████| 430/430 [00:02<00:00, 167.68it/s, v_num=0]
# Epoch 5:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 5:   0%|          | 2/430 [00:00<00:31, 13.59it/s, v_num=0]
# Epoch 5:   1%|          | 3/430 [00:00<00:21, 19.91it/s, v_num=0]
# Epoch 5:   5%|▍         | 21/430 [00:00<00:04, 83.78it/s, v_num=0]
# Epoch 5:   9%|▉         | 39/430 [00:00<00:03, 110.56it/s, v_num=0]
# Epoch 5:  14%|█▍        | 62/430 [00:00<00:02, 135.97it/s, v_num=0]
# Epoch 5:  19%|█▉        | 82/430 [00:00<00:02, 147.37it/s, v_num=0]
# Epoch 5:  24%|██▎       | 102/430 [00:00<00:02, 154.53it/s, v_num=0]
# Epoch 5:  28%|██▊       | 122/430 [00:00<00:01, 159.95it/s, v_num=0]
# Epoch 5:  33%|███▎      | 144/430 [00:00<00:01, 167.29it/s, v_num=0]
# Epoch 5:  39%|███▉      | 168/430 [00:00<00:01, 173.65it/s, v_num=0]
# Epoch 5:  44%|████▍     | 191/430 [00:01<00:01, 178.53it/s, v_num=0]
# Epoch 5:  50%|████▉     | 214/430 [00:01<00:01, 182.63it/s, v_num=0]
# Epoch 5:  54%|█████▍    | 233/430 [00:01<00:01, 184.02it/s, v_num=0]
# Epoch 5:  58%|█████▊    | 248/430 [00:01<00:01, 180.84it/s, v_num=0]
# Epoch 5:  62%|██████▏   | 268/430 [00:01<00:00, 181.29it/s, v_num=0]
# Epoch 5:  67%|██████▋   | 290/430 [00:01<00:00, 183.75it/s, v_num=0]
# Epoch 5:  72%|███████▏  | 310/430 [00:01<00:00, 184.20it/s, v_num=0]
# Epoch 5:  77%|███████▋  | 332/430 [00:01<00:00, 185.90it/s, v_num=0]
# Epoch 5:  82%|████████▏ | 352/430 [00:01<00:00, 186.50it/s, v_num=0]
# Epoch 5:  86%|████████▋ | 371/430 [00:01<00:00, 186.65it/s, v_num=0]
# Epoch 5:  91%|█████████▏| 393/430 [00:02<00:00, 188.54it/s, v_num=0]
# Epoch 5:  92%|█████████▏| 394/430 [00:02<00:00, 188.25it/s, v_num=0]
# Epoch 5:  92%|█████████▏| 394/430 [00:02<00:00, 188.22it/s, v_num=0]
# Epoch 5:  97%|█████████▋| 416/430 [00:02<00:00, 189.62it/s, v_num=0]
# Epoch 5:  97%|█████████▋| 417/430 [00:02<00:00, 189.78it/s, v_num=0]
# Epoch 5: 100%|██████████| 430/430 [00:02<00:00, 189.40it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 464.79it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 415.13it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 466.74it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 257.67it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 287.83it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 312.49it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 332.31it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 199.72it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 214.20it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 228.43it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 241.50it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 183.17it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 192.25it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 201.87it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 211.21it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 177.75it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 185.20it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 192.46it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 198.79it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 172.79it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 178.27it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 184.08it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 188.98it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 171.56it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 176.55it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 181.58it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 186.51it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 178.90it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 183.32it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 187.70it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 192.04it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 184.57it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 188.58it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 192.58it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 196.62it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 189.92it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 193.65it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 197.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 201.13it/s]
# Validation DataLoader 0: 100%|██████████| 40/40 [00:00<00:00, 204.35it/s]
# Epoch 5: 100%|██████████| 430/430 [00:02<00:00, 164.71it/s, v_num=0]
# Epoch 5: 100%|██████████| 430/430 [00:02<00:00, 164.67it/s, v_num=0]
# Epoch 6:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 6:   0%|          | 2/430 [00:00<00:42, 10.08it/s, v_num=0]
# Epoch 6:   5%|▌         | 23/430 [00:00<00:05, 76.24it/s, v_num=0]
# Epoch 6:   6%|▌         | 24/430 [00:00<00:05, 78.98it/s, v_num=0]
# Epoch 6:  11%|█         | 46/430 [00:00<00:03, 114.27it/s, v_num=0]
# Epoch 6:  16%|█▌        | 69/430 [00:00<00:02, 135.93it/s, v_num=0]
# Epoch 6:  21%|██        | 91/430 [00:00<00:02, 149.17it/s, v_num=0]
# Epoch 6:  26%|██▌       | 110/430 [00:00<00:02, 155.83it/s, v_num=0]
# Epoch 6:  30%|███       | 130/430 [00:00<00:01, 160.53it/s, v_num=0]
# Epoch 6:  35%|███▍      | 150/430 [00:00<00:01, 165.08it/s, v_num=0]
# Epoch 6:  40%|████      | 174/430 [00:01<00:01, 171.65it/s, v_num=0]
# Epoch 6:  46%|████▌     | 197/430 [00:01<00:01, 175.94it/s, v_num=0]
# Epoch 6:  51%|█████     | 220/430 [00:01<00:01, 180.02it/s, v_num=0]
# Epoch 6:  56%|█████▋    | 242/430 [00:01<00:01, 182.93it/s, v_num=0]
# Epoch 6:  61%|██████    | 263/430 [00:01<00:00, 184.98it/s, v_num=0]
# Epoch 6:  66%|██████▌   | 283/430 [00:01<00:00, 186.03it/s, v_num=0]
# Epoch 6:  68%|██████▊   | 294/430 [00:01<00:00, 180.53it/s, v_num=0]
# Epoch 6:  73%|███████▎  | 315/430 [00:01<00:00, 182.56it/s, v_num=0]
# Epoch 6:  79%|███████▉  | 339/430 [00:01<00:00, 185.38it/s, v_num=0]
# Epoch 6:  84%|████████▍ | 363/430 [00:01<00:00, 187.62it/s, v_num=0]
# Epoch 6:  90%|█████████ | 387/430 [00:02<00:00, 189.76it/s, v_num=0]
# Epoch 6:  94%|█████████▍| 405/430 [00:02<00:00, 189.55it/s, v_num=0]
# Epoch 6: 100%|█████████▉| 429/430 [00:02<00:00, 191.30it/s, v_num=0]
# Epoch 6: 100%|██████████| 430/430 [00:02<00:00, 191.27it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 419.39it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 323.01it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 297.56it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 323.62it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 322.48it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 296.21it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 297.03it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 309.01it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 307.40it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 295.25it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 301.76it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 309.39it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 308.10it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 252.50it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 259.06it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 266.85it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 276.23it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 246.95it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 251.66it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 256.88it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 258.56it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 231.74it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 235.77it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 239.55it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 241.04it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 222.30it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 225.44it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 228.84it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 232.54it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 215.68it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 219.13it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 222.70it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 227.41it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 215.28it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 219.55it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 223.76it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 228.00it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 217.63it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 221.50it/s]
# (RayTrainWorker pid=700925)
# Epoch 6: 100%|██████████| 430/430 [00:02<00:00, 168.21it/s, v_num=0]it/s]
# Epoch 6: 100%|██████████| 430/430 [00:02<00:00, 168.17it/s, v_num=0]
# Epoch 7:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 7:   3%|▎         | 11/430 [00:00<00:07, 59.48it/s, v_num=0]
# Epoch 7:   6%|▋         | 27/430 [00:00<00:04, 94.69it/s, v_num=0]
# Epoch 7:   7%|▋         | 28/430 [00:00<00:04, 91.72it/s, v_num=0]
# Epoch 7:  10%|▉         | 41/430 [00:00<00:03, 101.02it/s, v_num=0]
# Epoch 7:  14%|█▎        | 59/430 [00:00<00:03, 116.60it/s, v_num=0]
# Epoch 7:  18%|█▊        | 79/430 [00:00<00:02, 129.57it/s, v_num=0]
# Epoch 7:  23%|██▎       | 99/430 [00:00<00:02, 140.99it/s, v_num=0]
# Epoch 7:  28%|██▊       | 119/430 [00:00<00:02, 147.48it/s, v_num=0]
# Epoch 7:  33%|███▎      | 143/430 [00:00<00:01, 156.06it/s, v_num=0]
# Epoch 7:  39%|███▊      | 166/430 [00:01<00:01, 162.99it/s, v_num=0]
# Epoch 7:  44%|████▍     | 189/430 [00:01<00:01, 168.68it/s, v_num=0]
# Epoch 7:  44%|████▍     | 190/430 [00:01<00:01, 169.16it/s, v_num=0]
# Epoch 7:  49%|████▉     | 212/430 [00:01<00:01, 173.39it/s, v_num=0]
# Epoch 7:  50%|████▉     | 213/430 [00:01<00:01, 173.80it/s, v_num=0]
# Epoch 7:  54%|█████▎    | 231/430 [00:01<00:01, 174.80it/s, v_num=0]
# Epoch 7:  59%|█████▉    | 253/430 [00:01<00:01, 176.97it/s, v_num=0]
# Epoch 7:  63%|██████▎   | 273/430 [00:01<00:00, 178.41it/s, v_num=0]
# Epoch 7:  64%|██████▎   | 274/430 [00:01<00:00, 178.79it/s, v_num=0]
# Epoch 7:  64%|██████▎   | 274/430 [00:01<00:00, 178.77it/s, v_num=0]
# Epoch 7:  68%|██████▊   | 294/430 [00:01<00:00, 180.66it/s, v_num=0]
# Epoch 7:  73%|███████▎  | 316/430 [00:01<00:00, 182.15it/s, v_num=0]
# Epoch 7:  74%|███████▎  | 317/430 [00:01<00:00, 182.48it/s, v_num=0]
# Epoch 7:  76%|███████▌  | 327/430 [00:01<00:00, 177.86it/s, v_num=0]
# Epoch 7:  81%|████████▏ | 350/430 [00:01<00:00, 180.77it/s, v_num=0]
# Epoch 7:  86%|████████▋ | 371/430 [00:02<00:00, 181.51it/s, v_num=0]
# Epoch 7:  91%|█████████ | 390/430 [00:02<00:00, 182.49it/s, v_num=0]
# Epoch 7:  96%|█████████▌| 413/430 [00:02<00:00, 183.78it/s, v_num=0]
# Epoch 7: 100%|██████████| 430/430 [00:02<00:00, 183.67it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 433.92it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 429.39it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 342.83it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 370.23it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 341.70it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 364.64it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 268.26it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 267.17it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 219.53it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 222.68it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 212.36it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 220.16it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 201.38it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 207.61it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 201.40it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 205.86it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 201.01it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 208.62it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 202.53it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 208.73it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 206.35it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 212.74it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 207.00it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 212.51it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 204.96it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 210.45it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 209.75it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 213.83it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 196.64it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 201.27it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 205.94it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 210.45it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 192.80it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 196.88it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 201.01it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 204.04it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 197.05it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 200.80it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 204.58it/s]
# Epoch 7: 100%|██████████| 430/430 [00:02<00:00, 160.72it/s, v_num=0]it/s]
# Epoch 7: 100%|██████████| 430/430 [00:02<00:00, 160.68it/s, v_num=0]
# Epoch 8:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 8:   2%|▏         | 10/430 [00:00<00:07, 54.20it/s, v_num=0]
# Epoch 8:   3%|▎         | 11/430 [00:00<00:07, 57.96it/s, v_num=0]
# Epoch 8:   8%|▊         | 34/430 [00:00<00:03, 116.68it/s, v_num=0]
# Epoch 8:  13%|█▎        | 54/430 [00:00<00:02, 137.43it/s, v_num=0]
# Epoch 8:  16%|█▌        | 69/430 [00:00<00:02, 148.06it/s, v_num=0]
# Epoch 8:  19%|█▉        | 83/430 [00:00<00:02, 138.92it/s, v_num=0]
# Epoch 8:  23%|██▎       | 101/430 [00:00<00:02, 145.30it/s, v_num=0]
# Epoch 8:  27%|██▋       | 118/430 [00:00<00:02, 147.08it/s, v_num=0]
# Epoch 8:  27%|██▋       | 118/430 [00:00<00:02, 147.04it/s, v_num=0]
# Epoch 8:  32%|███▏      | 137/430 [00:00<00:01, 154.25it/s, v_num=0]
# Epoch 8:  32%|███▏      | 138/430 [00:00<00:01, 152.39it/s, v_num=0]
# Epoch 8:  37%|███▋      | 157/430 [00:00<00:01, 157.24it/s, v_num=0]
# Epoch 8:  42%|████▏     | 179/430 [00:01<00:01, 161.73it/s, v_num=0]
# Epoch 8:  42%|████▏     | 180/430 [00:01<00:01, 162.12it/s, v_num=0]
# Epoch 8:  46%|████▌     | 197/430 [00:01<00:01, 163.95it/s, v_num=0]
# Epoch 8:  46%|████▌     | 198/430 [00:01<00:01, 163.10it/s, v_num=0]
# Epoch 8:  51%|█████     | 220/430 [00:01<00:01, 167.19it/s, v_num=0]
# Epoch 8:  56%|█████▋    | 242/430 [00:01<00:01, 171.30it/s, v_num=0]
# Epoch 8:  57%|█████▋    | 243/430 [00:01<00:01, 171.20it/s, v_num=0]
# Epoch 8:  61%|██████    | 262/430 [00:01<00:00, 172.40it/s, v_num=0]
# Epoch 8:  65%|██████▌   | 280/430 [00:01<00:00, 172.53it/s, v_num=0]
# Epoch 8:  70%|███████   | 301/430 [00:01<00:00, 174.52it/s, v_num=0]
# Epoch 8:  75%|███████▌  | 323/430 [00:01<00:00, 176.91it/s, v_num=0]
# Epoch 8:  75%|███████▌  | 324/430 [00:01<00:00, 177.20it/s, v_num=0]
# Epoch 8:  80%|███████▉  | 343/430 [00:01<00:00, 178.06it/s, v_num=0]
# Epoch 8:  80%|████████  | 344/430 [00:01<00:00, 178.09it/s, v_num=0]
# Epoch 8:  83%|████████▎ | 357/430 [00:02<00:00, 175.47it/s, v_num=0]
# Epoch 8:  88%|████████▊ | 377/430 [00:02<00:00, 176.61it/s, v_num=0]
# Epoch 8:  88%|████████▊ | 378/430 [00:02<00:00, 176.82it/s, v_num=0]
# Epoch 8:  91%|█████████ | 392/430 [00:02<00:00, 176.03it/s, v_num=0]
# Epoch 8:  96%|█████████▌| 411/430 [00:02<00:00, 175.49it/s, v_num=0]
# Epoch 8: 100%|█████████▉| 429/430 [00:02<00:00, 175.56it/s, v_num=0]
# Epoch 8: 100%|██████████| 430/430 [00:02<00:00, 175.44it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 406.70it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 460.81it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 409.59it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 389.59it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 346.32it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 371.83it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 394.26it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 398.56it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 341.46it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 356.27it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 362.23it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 368.85it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 254.23it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 264.62it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 273.52it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 279.52it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 229.37it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 236.16it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 242.96it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 246.45it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 224.37it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 230.43it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 236.80it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 243.07it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 221.19it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 226.24it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 231.21it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 236.23it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 219.12it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 223.47it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 227.94it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 231.30it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 218.95it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 222.93it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 226.90it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 229.15it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 219.09it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 222.83it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 225.34it/s]
# Epoch 8: 100%|██████████| 430/430 [00:02<00:00, 155.07it/s, v_num=0]it/s]
# Epoch 8: 100%|██████████| 430/430 [00:02<00:00, 155.04it/s, v_num=0]
# Epoch 9:   0%|          | 0/430 [00:00<?, ?it/s, v_num=0]
# Epoch 9:   1%|▏         | 6/430 [00:00<00:12, 33.08it/s, v_num=0]
# Epoch 9:   6%|▌         | 26/430 [00:00<00:04, 93.45it/s, v_num=0]
# Epoch 9:  10%|▉         | 41/430 [00:00<00:03, 106.84it/s, v_num=0]
# Epoch 9:  10%|▉         | 42/430 [00:00<00:03, 108.64it/s, v_num=0]
# Epoch 9:  13%|█▎        | 56/430 [00:00<00:03, 115.45it/s, v_num=0]
# Epoch 9:  17%|█▋        | 72/430 [00:00<00:02, 123.46it/s, v_num=0]
# Epoch 9:  20%|██        | 88/430 [00:00<00:02, 127.40it/s, v_num=0]
# Epoch 9:  23%|██▎       | 101/430 [00:00<00:02, 127.21it/s, v_num=0]
# Epoch 9:  24%|██▎       | 102/430 [00:00<00:02, 128.04it/s, v_num=0]
# Epoch 9:  27%|██▋       | 116/430 [00:00<00:02, 129.96it/s, v_num=0]
# Epoch 9:  31%|███       | 133/430 [00:01<00:02, 132.79it/s, v_num=0]
# Epoch 9:  31%|███       | 133/430 [00:01<00:02, 132.77it/s, v_num=0]
# Epoch 9:  35%|███▌      | 152/430 [00:01<00:02, 137.82it/s, v_num=0]
# Epoch 9:  40%|███▉      | 171/430 [00:01<00:01, 141.87it/s, v_num=0]
# Epoch 9:  44%|████▎     | 188/430 [00:01<00:01, 143.63it/s, v_num=0]
# Epoch 9:  48%|████▊     | 207/430 [00:01<00:01, 147.38it/s, v_num=0]
# Epoch 9:  52%|█████▏    | 225/430 [00:01<00:01, 148.72it/s, v_num=0]
# Epoch 9:  57%|█████▋    | 243/430 [00:01<00:01, 151.48it/s, v_num=0]
# Epoch 9:  57%|█████▋    | 244/430 [00:01<00:01, 150.93it/s, v_num=0]
# Epoch 9:  61%|██████    | 263/430 [00:01<00:01, 153.06it/s, v_num=0]
# Epoch 9:  66%|██████▌   | 283/430 [00:01<00:00, 155.81it/s, v_num=0]
# Epoch 9:  70%|███████   | 303/430 [00:01<00:00, 157.89it/s, v_num=0]
# Epoch 9:  75%|███████▌  | 323/430 [00:02<00:00, 160.00it/s, v_num=0]
# Epoch 9:  80%|███████▉  | 342/430 [00:02<00:00, 160.66it/s, v_num=0]
# Epoch 9:  83%|████████▎ | 358/430 [00:02<00:00, 160.71it/s, v_num=0]
# Epoch 9:  85%|████████▌ | 367/430 [00:02<00:00, 157.32it/s, v_num=0]
# Epoch 9:  90%|█████████ | 387/430 [00:02<00:00, 159.05it/s, v_num=0]
# Epoch 9:  95%|█████████▍| 407/430 [00:02<00:00, 160.41it/s, v_num=0]
# Epoch 9:  99%|█████████▉| 426/430 [00:02<00:00, 161.18it/s, v_num=0]
# Epoch 9: 100%|██████████| 430/430 [00:02<00:00, 161.59it/s, v_num=0]
# (RayTrainWorker pid=700925)
# Validation: 0it [00:00, ?it/s]25)
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 359.90it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:00, 369.22it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:00, 374.46it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:00, 310.51it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:00, 283.59it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:00, 297.77it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:00, 306.80it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:00, 315.76it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:00, 322.42it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:00, 319.11it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:00, 291.74it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:00, 256.26it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:00, 260.24it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:00, 258.11it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:00<00:00, 222.11it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:00<00:00, 220.94it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:00<00:00, 226.27it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:00<00:00, 225.11it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:00<00:00, 219.67it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:00<00:00, 217.53it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:00<00:00, 221.41it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:00<00:00, 213.76it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:00<00:00, 203.51it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:00<00:00, 201.53it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:00<00:00, 205.95it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:00<00:00, 208.78it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:00<00:00, 211.53it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:00<00:00, 210.59it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:00<00:00, 213.71it/s]
# (RayTrainWorker pid=700925)
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:00<00:00, 208.28it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:00<00:00, 209.12it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:00<00:00, 210.86it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:00<00:00, 215.14it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:00<00:00, 200.98it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:00<00:00, 204.73it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:00<00:00, 207.79it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:00<00:00, 210.74it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:00<00:00, 202.75it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:00<00:00, 206.17it/s]
# Epoch 9: 100%|██████████| 430/430 [00:03<00:00, 143.13it/s, v_num=0]it/s]
# Epoch 9: 100%|██████████| 430/430 [00:03<00:00, 143.10it/s, v_num=0]
# Epoch 9: 100%|██████████| 430/430 [00:03<00:00, 138.32it/s, v_num=0]
# (RayTrainWorker pid=700925) `Trainer.fit` stopped: `max_epochs=10` reached.
# 2023-09-06 23:32:04,156	INFO tune.py:1148 -- Total run time: 37.65 seconds (37.63 seconds for the tuning loop).
# Validation Accuracy:  0.970507800579071
# Result(
#   metrics={'_report_on': 'train_epoch_end', 'train_loss': 0.05049066245555878, 'val_accuracy': 0.970507800579071, 'val_loss': -15.830514907836914, 'epoch': 9, 'step': 4300, 'should_checkpoint': True, 'done': True, 'trial_id': 'd3314_00000', 'experiment_tag': '0'},
#   path='/tmp/ray_results/ptl-mnist-example/LightningTrainer_d3314_00000_0_2023-09-06_23-31-26',
#   checkpoint=LightningCheckpoint(local_path=/tmp/ray_results/ptl-mnist-example/LightningTrainer_d3314_00000_0_2023-09-06_23-31-26/checkpoint_000009)
# )

# %% [markdown]
# ## Evaluate your model on test dataset

# %%
checkpoint: LightningCheckpoint = result.checkpoint
best_model: pl.LightningModule = checkpoint.get_model(MNISTClassifier)
# Out:
# Global seed set to 888

# %% [markdown]
# ### Single-node Testing

# %%
# Download and setup MNIST datamodule on the head node
datamodule.setup()
test_dataloader = datamodule.test_dataloader()

trainer = pl.Trainer()
result = trainer.test(best_model, dataloaders=test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3070') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Missing logger folder: /home/dino/Documents/Machine-Learning-Collection/ML/Ray-examples/ray-train/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.9775000214576721     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# ## Multi-node Testing

# %%
import ray
import pytorch_lightning as pl

from pytorch_lightning.plugins.environments import (
    LightningEnvironment,
)
from ray.air.util.torch_dist import (
    TorchDistributedWorker,
    init_torch_dist_process_group,
    shutdown_torch_dist_process_group,
)


class RayEnvironment(LightningEnvironment):
    """Setup Lightning DDP training environment for Ray cluster."""

    def world_size(self) -> int:
        return int(os.environ["WORLD_SIZE"])

    def global_rank(self) -> int:
        return int(os.environ["RANK"])

    def local_rank(self) -> int:
        return int(os.environ["LOCAL_RANK"])

    def set_world_size(self, size: int) -> None:
        # Disable it since `world_size()` directly returns data from AIR session.
        pass

    def set_global_rank(self, rank: int) -> None:
        # Disable it since `global_rank()` directly returns data from AIR session.
        pass

    def teardown(self):
        pass


@ray.remote
class TestWorker(TorchDistributedWorker):
    def run(self):
        trainer = pl.Trainer(
            num_nodes=num_workers,
            accelerator="gpu",
            strategy="ddp",
            plugins=[RayEnvironment()],
        )
        return trainer.test(best_model, dataloaders=test_dataloader)


# Create 4 remote Ray Actors, each with 1 GPU
workers = [TestWorker.options(num_gpus=1).remote() for _ in range(num_workers)]

# Initialize the Torch distributed group among the 4 actors.
# This will set up the required environment variables including 
# RANK, LOCAL_RANK, WORLD_SIZE, MASTER_ADDRESS, ...
init_torch_dist_process_group(workers=workers, backend="nccl")

# Execute the testing run in parallel
results = ray.get([worker.run.remote() for worker in workers])

# Shutdown the process group
shutdown_torch_dist_process_group(workers=workers)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 4
#       1 import ray
#       2 import pytorch_lightning as pl
# ----> 4 from pytorch_lightning.plugins.environments.lightning_environment import (
#       5     LightningEnvironment,
#       6 )
#       7 from ray.air.util.torch_dist import (
#       8     TorchDistributedWorker,
#       9     init_torch_dist_process_group,
#      10     shutdown_torch_dist_process_group,
#      11 )
#      14 class RayEnvironment(LightningEnvironment):
#
# ModuleNotFoundError: No module named 'pytorch_lightning.plugins.environments.lightning_environment'
